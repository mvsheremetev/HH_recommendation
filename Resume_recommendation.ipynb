# %%
import pandas as pd
import re
import nltk
from pymystem3 import Mystem
from nltk.corpus import stopwords as nltk_stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from bs4 import BeautifulSoup

# %% [markdown]
# Задаем количество резюме в рекоментадельной выдаче.

# %%
TOP_COUNT = 30

# %% [markdown]
# Подгружаем текст из файла резюме ./data/vacancy/vacancy.html - этот файл заранее сохранен с сайта hh.ru.

# %%
with open('./data/vacancy/vacancy.html') as vacancy_page:
    soup = BeautifulSoup(vacancy_page, features="lxml")
    
def extract_vacancy_information(tag: str, attributes: dict):
    finder = soup.find_all(tag, attributes)
    if len(finder) == 1:
        finder = finder[0].get_text()
        return finder
    elif len(finder) > 1:
        listed_info = []
        for part in finder:
            list_element = part.get_text()
            listed_info.append(list_element)
    else:
        return "No information"
    
vacancy_description = extract_vacancy_information('div', {'data-qa': "vacancy-description"})

# %%
vacancy_description
# Out:
# 'Вакансия открыта для отбора 2 кандидатов! Компания Fitness Нolding приглашает в команду проекта ZFitness на должность менеджера по продажам.Компания Fitness Нolding имеет репутацию надёжного и стабильного работодателя с 2003 года. Здесь вы найдёте возможность высокого заработка, карьерный рост, личное и профессиональное развитие, сплочённую и сильную команду, внимание и уважение со стороны коллег и руководителей, обучение и тренинги за счет компании.Требования к кандидату: - образование высшее, неоконченное высшее; - успешный опыт в продажах в сфере услуг; - нацеленность на высокий личный и командный результат; - базовые знания техник продаж и ведения переговоров; - готовность учиться и развиваться; - клиентоориентированность; - грамотная ,хорошо поставленная речь; - активность, стремление быть лучшим в продажах ; - готовность создавать и поддерживать высокий уровень сервиса; - знание ПК Word, Excel;   Обязанности: - входящая и исходящая работа по телефону(по теплой базе); - проведение презентации клуба; - продажа клубных карт действующим и потенциальным членам клуба; - активное привлечение новых клиентов; - выполнение личного и коллективного плана продаж; - ведение документооборота;Условия:  высокий уровень заработной платы (обсуждается индивидуально с кандидатом); график работы 5/2 с плавающими выходными; работа в команде молодых , энергичных ,близких по духу коллег; возможность учиться делу у лучших экспертов продаж в фитнес-индустрии; тренинги и обучение за счет компании; возможность карьерного роста как в клубе ,так и в компании FitnessHolding; корпоративные скидки на дополнительные услуги клуба вам и вашим родным; скидка на питание; территориально: м. Братиславская (1 мин. пешком); полный рабочий день. '

# %% [markdown]
# Подгружаем датафрейм с соискателями.

# %%
candidates = pd.read_csv('./data/merged/merged_file.csv')

# %%
df = candidates.copy()

# %%
df.head()
# Out:
#    Unnamed: 0                                      id  \
# 0           0  4ad624ac0007f57b790039ed1f533448333337
# 1           1  cfb865b70002ffc1360039ed1f704436587438
# 2           2  8a7cdf1d0000749f6c0039ed1f736563726574
# 3           3  bc44cd50000178f56c0039ed1f3162566d664b
# 4           4  d9b39a3d000739766d0039ed1f6979784b5076
#
#                                  title     city  age   gender  \
# 0                 менеджер по продажам  Воронеж   21  Мужчина
# 1               Специалист по продажам   Москва   51  Мужчина
# 2                Менеджер по продажам    Москва   35  Мужчина
# 3                 Менеджер по продажам   Москва   49  Мужчина
# 4  Менеджер по продаже запасных частей   Москва   48  Мужчина
#
#                    area  desired_wage  work_experience  \
# 0         Строительство         35000             11.0
# 1        Начало карьеры        137000             10.7
# 2  Автомобильный бизнес        100000             16.6
# 3               Продажи        120000             14.8
# 4               Продажи         50000             18.6
#
#                               experience_description  \
# 0  ['Консультировании покупателей\n-активные прод...
# 1  ['работа в СРМ, 1С, В2В,В2С, Поиск клиентов, П...
# 2  ['Ведение сделки по продаже автомобиля от перв...
# 3  ['-Планирование продаж\n-Определение и согласо...
# 4  Опыт работы на платформе ABCP, 1С, работ с кат...
#
#                    education_level                                  languages  \
# 0  Неоконченное высшее образование  {'Русский': 'Родной', 'Английский': 'A2'}
# 1               Высшее образование  {'Русский': 'Родной', 'Английский': 'A1'}
# 2               Высшее образование  {'Русский': 'Родной', 'Английский': 'B2'}
# 3               Высшее образование                      {'Russian': 'Native'}
# 4                      Образование                      {'Russian': 'Native'}
#
#                                               skills
# 0  ['Энергичность', 'Стрессоустойчивость', 'Быстр...
# 1  ['Ведение переговоров', 'Закупки', '1С: CRM ПР...
# 2  ['MS Office', 'MS Outlook', '1С: Предприятие 8...
# 3  Сохраняю продуктивность даже в форс-мажорных с...
# 4                                Большой опыт работы

# %% [markdown]
# Удаляем лишнюю для нас информацию и приводим оставшуюся к нижнему регистру. Описание опыта будет приведено к нижнему регистру на этапе лемматизации.

# %%
df.drop(['Unnamed: 0', 'title', 'education_level', 'languages', 'skills'], inplace=True, axis=1)
df['city'] = df['city'].apply(lambda x: x.lower())
df['gender'] = df['gender'].apply(lambda x: x.lower())
df['area'] = df['area'].apply(lambda x: x.lower())
df.head()
# Out:
#                                        id     city  age   gender  \
# 0  4ad624ac0007f57b790039ed1f533448333337  воронеж   21  мужчина
# 1  cfb865b70002ffc1360039ed1f704436587438   москва   51  мужчина
# 2  8a7cdf1d0000749f6c0039ed1f736563726574   москва   35  мужчина
# 3  bc44cd50000178f56c0039ed1f3162566d664b   москва   49  мужчина
# 4  d9b39a3d000739766d0039ed1f6979784b5076   москва   48  мужчина
#
#                    area  desired_wage  work_experience  \
# 0         строительство         35000             11.0
# 1        начало карьеры        137000             10.7
# 2  автомобильный бизнес        100000             16.6
# 3               продажи        120000             14.8
# 4               продажи         50000             18.6
#
#                               experience_description
# 0  ['Консультировании покупателей\n-активные прод...
# 1  ['работа в СРМ, 1С, В2В,В2С, Поиск клиентов, П...
# 2  ['Ведение сделки по продаже автомобиля от перв...
# 3  ['-Планирование продаж\n-Определение и согласо...
# 4  Опыт работы на платформе ABCP, 1С, работ с кат...

# %% [markdown]
# Лемматизируем описание опыта. Описание вакансии добавим в датафрейм последней строкой - это нужно для того, чтобы векторизация текста вакансии происходила одновременно с векторизацией текстов резюме и их размерность была одинакова. Также при этом векторизация будет учитывать частоту появления слов из описания вакансии во всем корпусе текста.

# %%
m = Mystem()

def lemmatize_text(text):
    text = text.lower()
    lemm_text = ''.join(m.lemmatize(text.lower()))
    cleared_text = re.sub(r'[^а-яА-яёË]', ' ', lemm_text) 
    return ' '.join(cleared_text.split())

new_row = {'experience_description': vacancy_description}
df = df.append(new_row, ignore_index=True)
df['experience_description'] = df['experience_description'].apply(lemmatize_text)

# %% [markdown]
# Векторизируем текст посредством TfidfVectorizer.

# %%
nltk.download('stopwords')
stopwords = set(nltk_stopwords.words('russian'))

count_tf_idf = TfidfVectorizer(stop_words=stopwords, ngram_range=(1, 3))
experience_description_vectorized = count_tf_idf.fit_transform(df['experience_description'].values.astype('U'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/msher/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Вычисляем косинусное расстояние между векторами, полученными из текстов резюме и вектором, полученным из текста описания вакансии.

# %%
def count_cosine_similarity(row):
    return cosine_similarity(experience_description_vectorized[row.name],
                             experience_description_vectorized[experience_description_vectorized.shape[0] - 1])

# %%
df['cosine_similarity'] = df.apply(count_cosine_similarity, axis=1)

# %% [markdown]
# Выводим полученный датафрейм, отстортированный по убыванию cosine_similarity.

# %%
df.drop(index=experience_description_vectorized.shape[0] - 1, inplace=True)
df.sort_values(by = 'cosine_similarity', ascending=False).head(TOP_COUNT)
# Out:
#                                           id             city   age   gender  \
# 2279  bf4952af00053c0fd40039ed1f656a5a355373           москва  31.0  мужчина
# 3317  37f7c7a80002ebd3920039ed1f67484a765476           москва  28.0  женщина
# 4627  f6aa1bb7000436f1ce0039ed1f4c4f58774142           москва  25.0  женщина
# 2163  4c6057c60005696ba30039ed1f37554a587045           москва  28.0  мужчина
# 1103  4c6b15c8000594255f0039ed1f6764724d6733           москва  37.0  мужчина
# 4920  8dc100ff0003275ce20039ed1f556a6b4d4963           москва  24.0  женщина
# 770   914487fa0006aa18980039ed1f5355774f5141           москва  24.0  женщина
# 2903  09031f330002fb81320039ed1f396f54697a69           москва  29.0  мужчина
# 2684  85fd8e5a0004197a870039ed1f74335470706f           москва  24.0  женщина
# 1444  7694e177000204e2dd0039ed1f50434757584d           москва  25.0  мужчина
# 2784  d9e6786a0007a3ae670039ed1f3572437a6b73           москва  26.0  женщина
# 330   8dae88ed00071cda2b0039ed1f6d776b53734d           москва  24.0  женщина
# 2743  fd8deefc00070d58220039ed1f45434d35554f           москва  25.0  женщина
# 4483  57dab77700024c38460039ed1f776c70767063           москва  28.0  женщина
# 456   d2ae091b000812dfea0039ed1f63396e6c4636           москва  21.0  женщина
# 4011  92a08b1100044dd3740039ed1f69774e434a37           москва  37.0  женщина
# 3393  a064a4850005d5b8700039ed1f37724d61784e           москва  29.0  женщина
# 1661  81479b3500073109b40039ed1f326c68714871           москва  22.0  женщина
# 1653  2cc2df140005ab38f30039ed1f415a30566b6f           москва  27.0  мужчина
# 1171  745f0d6500014d70130039ed1f507641545242  санкт-петербург  37.0  мужчина
# 4561  9df0dd420008b178b20039ed1f736250397069  санкт-петербург  25.0  женщина
# 3474  a8806b30000727298e0039ed1f326d524c7739           москва  21.0  мужчина
# 817   936c9bde0002098c0b0039ed1f75497275576a  санкт-петербург  35.0  мужчина
# 4697  12b873c5000766cec60039ed1f36554c763835           москва  29.0  женщина
# 1544  0d3b6080000178ee6e0039ed1f4c6f776a4776           москва  30.0  женщина
# 4642  cf6b3ac60008f1a1ce0039ed1f4652394b3179           москва  35.0  мужчина
# 4802  b7e5ff66000838c8b30039ed1f56514278666f           москва  24.0  мужчина
# 356   8d285c9200016baa280039ed1f386d5257456a           москва  31.0  женщина
# 1015  dd1e133300065024980039ed1f444968774946           москва  34.0  мужчина
# 4882  a628ae2500028fbe340039ed1f474a35626535           москва  28.0  мужчина
#
#                   area  desired_wage  work_experience  \
# 2279  спортивные клубы       90000.0             9.70
# 3317           продажи      150000.0             6.90
# 4627           продажи      100000.0             6.60
# 2163  спортивные клубы       80000.0             5.20
# 1103  спортивные клубы       70000.0            10.11
# 4920  спортивные клубы       60000.0             4.10
# 770              банки       90000.0             3.80
# 2903           продажи      200000.0             6.30
# 2684         маркетинг       80000.0             3.90
# 1444           продажи       80000.0             4.50
# 2784           продажи       90000.0             5.00
# 330   спортивные клубы       50000.0             5.40
# 2743           продажи      120000.0             5.90
# 4483  спортивные клубы      100000.0             3.10
# 456     начало карьеры       60000.0             1.50
# 4011  спортивные клубы       80000.0             4.00
# 3393  спортивные клубы      100000.0             5.20
# 1661           продажи      150000.0             3.90
# 1653     строительство      200000.0             4.60
# 1171           продажи       80000.0             9.60
# 4561  спортивные клубы       90000.0             4.30
# 3474           продажи       60000.0             2.20
# 817   спортивные клубы       50000.0            15.11
# 4697  спортивные клубы       80000.0            11.60
# 1544  спортивные клубы       50000.0             8.60
# 4642           продажи      125000.0            11.50
# 4802  спортивные клубы       80000.0             3.00
# 356            продажи      150000.0             7.40
# 1015           продажи       90000.0            11.60
# 4882  спортивные клубы      100000.0             4.00
#
#                                  experience_description  \
# 2279  продажа клубный карта консультирование клиент ...
# 3317  регулярный выполнение личный и коллективный пл...
# 4627  обязанность общий руководство проект контроль ...
# 2163  встреча гость обработка входить поток работа с...
# 1103  консультация клиент по весь вид услуга клуб пп...
# 4920  прием и качественный обработка входить заявка ...
# 770   работа с зарплатной клиент банк звонок встреча...
# 2903  работа на этап строительство клуб продажа клуб...
# 2684  продажа клубный карта фитнес клуб консультация...
# 1444  прием и обработка входить заявка подбор трансп...
# 2784  прием входить звонок и совершение исходить по ...
# 330   встреча клиент показ клуб работа с возражение ...
# 2743  продажа клубный карта консультирование клиент ...
# 4483  работа на предпродажа клуб пприем входить звон...
# 456   прием входить звонок продление контракт действ...
# 4011  управление отдел продажа фитнес клуб обучение ...
# 3393  выполнение личный и коллективный план отдел пр...
# 1661  работа на входящий поток интернет холодный пои...
# 1653  консультирование клиент в офис продажа на объе...
# 1171  должностной обязанность продажа телекоммуникац...
# 4561  полный цикл продажа работа с клиент веление кл...
# 3474  презентация фитнес клуб продажа клубный членст...
# 817   продажа оборудование и комплектующий ведение к...
# 4697  выполнение и перевыполнение план продажа разра...
# 1544  ведение коммерческий переговоры с клиент в инт...
# 4642  мой основной принцип работа с клиент пкаждый п...
# 4802  продажа клубный карта выполнение личный и клуб...
# 356   выполнение личный и общий план продажа пбизнес...
# 1015  работа с входящий поток клиент и звонок выполн...
# 4802  Мужчина  Спортивные клубы         80000             3.00
# 356   Женщина           Продажи        150000             7.40
# 1015  Мужчина           Продажи         90000            11.60
# 4882  Мужчина  Спортивные клубы        100000             4.00
#
#                                  experience_description  \
# 2279  ['- Продажа клубных карт\n- Консультирование к...
# 3317  ['- регулярное выполнение личного и коллективн...
# 4627  ['Обязанности: \n1. Общее руководство проектом...
# 2163  ['Встреча гостей, обработка входящего потока, ...
# 1103  ['Консультация клиентов по всем видам услуг кл...
# 4920  ['Приём и качественная обработка входящих заяв...
# 770   ['-работа с зарплатными клиентами банка (звонк...
# 2903  ['-Работа на этапе строительства клуба, \n-Про...
# 2684  ['Продажа клубных карт фитнес клуба ', 'Консул...
# 1444  ['— приём и обработка входящих заявок;\n— подб...
# 2784  ['Приём входящих звонков и совершение исходящи...
# 330   ['Встреча клиентов, показ клуба, работа с возр...
# 2743  ['Продажа клубных карт, консультирование клиен...
# 4483  ['Работа на предпродажах клуба\nПрием входящих...
# 456   ['Прием входящих звонков. Продление контрактов...
# 4011  ['- Управление отделом продаж фитнес клуба\n- ...
# 3393  ['Выполнение личного и коллективного плана отд...
# 1661  ['Работа на входящем потоке (интернет + холодн...
# 1653  ['Консультирование клиентов в офисе продаж на ...
# 1171  ['Должностные обязанности:\n- продажа телекомм...
# 4561  ['- полный цикл продаж; \n- работа с клиентами...
# 3474  ['1. Презентация фитнес-клуба, продажа клубног...
# 817   ['- Продажа оборудования и комплектующих; \n- ...
# 4697  ['Выполнение и перевыполнение плана продаж', '...
# 1544  ['-ведение коммерческих переговоров с -клиента...
# 4642  ['Мой основной принцип работы с клиентами:\nКа...
# 4802  ['Продажа клубных карт, выполнение личного и к...
# 356   ['Выполнение личного и общего плана продаж.\nБ...
# 1015  ['Работа с входящим потоком клиентов и звонков...
# 4882  ['Поиск и привлечение новых клиентов (обработк...
#
#                       education_level  \
# 2279               Высшее образование
# 3317               Высшее образование
# 4627                      Образование
# 2163               Высшее образование
# 1103               Высшее образование
# 4920    Высшее образование (Бакалавр)
# 770                Высшее образование
# 2903               Высшее образование
# 2684               Высшее образование
# 1444               Высшее образование
# 2784    Высшее образование (Бакалавр)
# 330   Неоконченное высшее образование
# 2743               Высшее образование
# 4483  Среднее специальное образование
# 456   Неоконченное высшее образование
# 4011               Высшее образование
# 3393               Высшее образование
# 1661  Неоконченное высшее образование
# 1653    Высшее образование (Бакалавр)
# 1171              Среднее образование
# 4561  Неоконченное высшее образование
# 3474  Среднее специальное образование
# 817                Высшее образование
# 4697               Высшее образование
# 1544              Среднее образование
# 4642               Высшее образование
# 4802  Среднее специальное образование
# 356                Высшее образование
# 1015               Высшее образование
# 4882     Высшее образование (Магистр)
#
#                                               languages  \
# 2279                              {'Russian': 'Native'}
# 3317          {'Русский': 'Родной', 'Английский': 'A1'}
# 4627          {'Русский': 'Родной', 'Английский': 'B1'}
# 2163          {'Русский': 'Родной', 'Английский': 'A1'}
# 1103                              {'Russian': 'Native'}
# 4920          {'Русский': 'Родной', 'Английский': 'B2'}
# 770                               {'Russian': 'Native'}
# 2903          {'Русский': 'Родной', 'Английский': 'B1'}
# 2684          {'Русский': 'Родной', 'Английский': 'A1'}
# 1444  {'Русский': 'Родной', 'Английский': 'B1', 'Кур...
# 2784          {'Русский': 'Родной', 'Английский': 'A1'}
# 330           {'Русский': 'Родной', 'Английский': 'A1'}
# 2743                              {'Russian': 'Native'}
# 4483                              {'Russian': 'Native'}
# 456           {'Русский': 'Родной', 'Английский': 'A1'}
# 4011                              {'Russian': 'Native'}
# 3393          {'Русский': 'Родной', 'Английский': 'B2'}
# 1661  {'Русский': 'Родной', 'Английский': 'A1', 'Нем...
# 1653          {'Русский': 'Родной', 'Английский': 'A1'}
# 1171  {'Русский': 'Родной', 'Английский': 'A1', 'Бел...
# 4561          {'Русский': 'Родной', 'Английский': 'B1'}
# 3474                              {'Russian': 'Native'}
# 817           {'Русский': 'Родной', 'Английский': 'C1'}
# 4697          {'Русский': 'Родной', 'Английский': 'A1'}
# 1544  {'Русский': 'Родной', 'Английский': 'A1', 'Фра...
# 4642  {'Русский': 'Родной', 'Английский': 'A1', 'Нем...
# 4802          {'Русский': 'Родной', 'Английский': 'A1'}
# 356           {'Русский': 'Родной', 'Английский': 'A1'}
# 1015                              {'Russian': 'Native'}
# 4882          {'Русский': 'Родной', 'Английский': 'B2'}
#
#                                                  skills
# 2279  ['Опыт в сфере продаж', 'Знание методик активн...
# 3317  ['Работа в команде', 'Навыки продаж', 'Прямые ...
# 4627                                     No information
# 2163  ['Активные продажи', 'Консультирование клиенто...
# 1103                                     No information
# 4920  ['Умение работать в команде', 'Работа с кассой...
# 770   ['Холодные продажи', 'Поиск и привлечение клие...
# 2903  ['Умение работать в команде', 'Прием и распред...
# 2684  ['Ответственность', 'Добросовестность', 'Креат...
# 1444  ['Деловое общение', 'Внутренние коммуникации',...
# 2784  ['Холодные продажи', 'Поиск и привлечение клие...
# 330    ['А&А', '1С', 'R-Keeper', 'MS Excel', 'MS Word']
# 2743  ПК , excel , word. 1S, A&A, club manager , clu...
# 4483                                     No information
# 456                                    Исполнительность
# 4011             ['1C: Бухгалтерия', 'Пользователь ПК']
# 3393  ['Работа с большим объемом информации', 'Работ...
# 1661  ['Контроль работы промоутеров', 'работа с теку...
# 1653  ['Деловая переписка', 'CRM', 'Активные продажи...
# 1171  ['B2B Продажи', 'Ведение активных клиентов', '...
# 4561  ['Организаторские навыки', 'Организация меропр...
# 3474  ['Уверенный пользователь MSoffice', 'MS Outloo...
# 817   ['Adobe Photoshop, Corel Draw, Macromedia Flas...
# 4697  ['Внутренние коммуникации', 'Антикризисные ком...
# 1544  ['Знание техники продаж', 'Навыки переговоров'...
# 4642  ['Управление продажами', 'Формирование цели', ...
# 4802  ['Грамотная речь', 'Пользователь ПК', 'Электро...
# 356   ['Работа с возражениями', 'Холодные продажи', ...
# 1015  ['Поиск и привлечение клиентов', 'Ведение клие...
# 4882  ['общительный', 'Работоспособность', 'вынослив...
